# %% [markdown]
# # Environment check
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Z-Denis/cecam-nqs/blob/main/notebooks/00_environment_check.ipynb)
#
# This notebook verifies that the course environment is correctly installed.

# %%
# IF AND ONLY IF you are running this notebook on Google Colab:

# On a CPU runtime, uncomment and run:
# %pip uninstall -y jax jaxlib jax-cuda12-plugin jax-cuda12-pjrt
# %pip install -q "jax==0.10.1" "jaxlib==0.10.1"
# %pip install -q git+https://github.com/Z-Denis/cecam-nqs.git

# On a T4 GPU runtime, uncomment and run:
# %pip install -q "jax[cuda12]==0.10.1"
# %pip install -q git+https://github.com/Z-Denis/cecam-nqs.git

# %%
import sys
import jax
import netket as nk
import cecam_nqs

print(sys.version)
print(sys.executable)
print("JAX:", jax.__version__)
print("NetKet:", nk.__version__)
print("cecam_nqs:", cecam_nqs.__version__)
print(jax.devices())
# Out:
# ∣NK⟩ Tip: vstate.check_mc_convergence(H) diagnoses whether your sampler is well-mixed and recommends a sweep_size.
# 3.12.6 (main, Sep  6 2024, 19:03:47) [Clang 15.0.0 (clang-1500.3.9.4)]
# /Users/deniszakari/Documents/numerics/repos/cecam-nqs/.venv/bin/python
# JAX: 0.10.1
# NetKet: 3.22.3
# cecam_nqs: 0.1.0
# [CpuDevice(id=0)]
